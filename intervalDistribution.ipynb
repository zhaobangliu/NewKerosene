# %%
import pandas as pd
import matplotlib.pyplot as plt
from modules.kerosenePreprocess import Kerosene
from modules import drawing as dr;
plt.rcParams['figure.figsize'] = [10, 5]
pd.options.display.max_rows = 400

# %%
kerosene = Kerosene("./raw_data/2-supply-histories-with-sensor.csv")
# some special id to drop
kerosene.normal_use.set_index("customer_id", inplace=True)
kerosene.normal_use.drop([666, 663, 650, 1086], inplace=True)
kerosene.normal_use.reset_index(inplace=True)
# kerosene.threeGroups("./raw_data/weather_data.csv")
normalUse = kerosene.normal_use.copy()
# Out:
# c:\Users\zhaobang\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dr.draw_OneID_Refuel(831, normalUse)

# %%
normalUse.tail()
# Out:
#        customer_id  index  tank_type_id         supplied_at  volume purpose
# 14001          831  28985             1 2018-12-12 11:08:00     0.0     NaN
# 14002          831  28986             1 2019-01-15 16:02:00   224.8     NaN
# 14003          831  28987             1 2019-02-12 15:11:00   109.8     NaN
# 14004          831  28988             1 2019-03-19 10:25:00     0.0     NaN
# 14005          831  28989             1 2019-04-17 10:59:00   148.8     NaN

# %%
dr.draw_interval_distribution(normalUse, "customer_id", "supplied_at")
