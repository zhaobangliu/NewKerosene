# %%
import pandas as pd
import numpy as np
PATH_PRE = "./Appolo/A_Dataset/highccgroup/PreDataset.csv"
PATH_PRICE = "./raw_data/kerosene_price.csv"
PATH_SAVE = "./Appolo/A_Dataset/highccgroup/Train_Test.csv"

# %%
df = pd.read_csv(PATH_PRE)
df_price = pd.read_csv(PATH_PRICE)
df["supplied_at"] = pd.to_datetime(df["supplied_at"], format="%Y-%m-%d %X")
df_price["date"] = pd.to_datetime(df_price["date"], format="%Y-%m")

# %%
# Using 椿データ we need to drop purepose
df.pop("purpose")
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 3059   NaN
# 3060   NaN
# 3061   NaN
# 3062   NaN
# 3063   NaN
# Name: purpose, Length: 3064, dtype: float64

# %%
df.loc[1, "supplied_at"]
# Out:
# Timestamp('2020-12-03 10:20:00')

# %%
len(df)
# Out:
# 18900

# %%
df["last_supply_time"] = ""
for i in range(0, len(df) - 1):
    if df.loc[i+1, "customer_id"] == df.loc[i, "customer_id"]:
        df.loc[i+1, "last_supply_time"] = df.loc[i, "supplied_at"]

# %%
df
# Out:
#        customer_id         supplied_at  volume  size     sum       mean  \
# 0            251.0 2020-11-20 08:26:00   109.8   198  1653.9  11.729787
# 1            251.0 2020-12-03 10:20:00   124.3   198  1653.9  11.729787
# 2            251.0 2020-12-18 09:32:00   177.9   198  1653.9  11.729787
# 3            251.0 2020-12-29 13:51:00   144.6   198  1653.9  11.729787
# 4            251.0 2021-01-13 16:15:00   248.7   198  1653.9  11.729787
# ...            ...                 ...     ...   ...     ...        ...
# 18895    8622770.0 2021-11-08 14:37:00   151.7   446   543.5   4.529167
# 18896    8622770.0 2021-12-08 10:03:00    86.7   446   543.5   4.529167
# 18897    8622770.0 2022-01-08 17:01:00   159.8   446   543.5   4.529167
# 18898    8622770.0 2022-02-11 09:30:00   169.8   446   543.5   4.529167
# 18899    8622770.0 2022-03-10 14:09:00   127.2   446   543.5   4.529167
#
#          matemp     mltemp    mhtemp     mwind    msnowacc     msnow  \
# 0           NaN        NaN       NaN       NaN         NaN       NaN
# 1     -2.300000  -0.138462 -4.353846  2.730769    1.000000  0.769231
# 2      0.100000   2.486667 -2.766667  2.980000    1.333333  0.800000
# 3      2.745455   5.863636 -0.290909  3.036364   11.727273  2.545455
# 4      6.440000  10.193333  3.253333  2.340000   28.066667  4.266667
# ...         ...        ...       ...       ...         ...       ...
# 18895       NaN        NaN       NaN       NaN         NaN       NaN
# 18896 -5.710000  -2.293333 -8.980000  3.543333    0.866667  0.600000
# 18897  2.629032   5.838710 -0.506452  3.116129   31.451613  4.193548
# 18898  2.900000   6.247059  0.038235  3.094118   85.441176  6.352941
# 18899  0.485185   3.622222 -2.518519  3.577778  103.000000  3.370370
#
#            msun    mhumidi  mean_consumption  interval     last_supply_time
# 0           NaN        NaN               NaN       NaN
# 1      1.976923  67.000000          9.561538      13.0  2020-11-20 08:26:00
# 2      3.800000  62.466667         11.860000      15.0  2020-12-03 10:20:00
# 3      2.390909  68.454545         13.145455      11.0  2020-12-18 09:32:00
# 4      3.853333  69.066667         16.580000      15.0  2020-12-29 13:51:00
# ...         ...        ...               ...       ...                  ...
# 18895       NaN        NaN               NaN       NaN  2021-04-27 14:49:00
# 18896  3.303333  69.866667          2.890000      30.0  2021-11-08 14:37:00
# 18897  3.287097  71.290323          5.154839      31.0  2021-12-08 10:03:00
# 18898  3.611765  73.558824          4.994118      34.0  2022-01-08 17:01:00
# 18899  3.937037  70.296296          4.711111      27.0  2022-02-11 09:30:00
#
# [18900 rows x 17 columns]

# %%
dataset = df.copy()
dataset_final = dataset.copy()
for i in dataset.index:
    if np.isnan(dataset.loc[i, "matemp"]):
        dataset_final.drop(i, inplace=True)
dataset_final.reset_index(inplace=True, drop=True)

# %%
dataset_final.head()
# Out:
#    customer_id         supplied_at  volume  size     sum       mean    matemp  \
# 0        251.0 2020-12-03 10:20:00   124.3   198  1653.9  11.729787 -2.300000
# 1        251.0 2020-12-18 09:32:00   177.9   198  1653.9  11.729787  0.100000
# 2        251.0 2020-12-29 13:51:00   144.6   198  1653.9  11.729787  2.745455
# 3        251.0 2021-01-13 16:15:00   248.7   198  1653.9  11.729787  6.440000
# 4        251.0 2021-01-28 08:15:00   199.6   198  1653.9  11.729787  3.160000
#
#       mltemp    mhtemp     mwind   msnowacc     msnow      msun    mhumidi  \
# 0  -0.138462 -4.353846  2.730769   1.000000  0.769231  1.976923  67.000000
# 1   2.486667 -2.766667  2.980000   1.333333  0.800000  3.800000  62.466667
# 2   5.863636 -0.290909  3.036364  11.727273  2.545455  2.390909  68.454545
# 3  10.193333  3.253333  2.340000  28.066667  4.266667  3.853333  69.066667
# 4   6.986667 -0.220000  3.560000  45.200000  3.933333  3.166667  71.800000
#
#    mean_consumption  interval     last_supply_time
# 0          9.561538      13.0  2020-11-20 08:26:00
# 1         11.860000      15.0  2020-12-03 10:20:00
# 2         13.145455      11.0  2020-12-18 09:32:00
# 3         16.580000      15.0  2020-12-29 13:51:00
# 4         13.306667      15.0  2021-01-13 16:15:00

# %%
len(dataset_final)
# Out:
# 16229

# %%
dataset_final["last_year_mean"] = ""
dataset_final["last_year_sum"] = ""
unique_id = pd.unique(dataset_final["customer_id"])

# add last year data
for id in unique_id:
    df_id = dataset_final[dataset_final["customer_id"]==id]
    df_id.reset_index(inplace=True)
    for i in range(len(df_id)-1):
        if df_id.loc[i+1, "supplied_at"].month - df_id.loc[i, "supplied_at"].month > 6:
            for j in range(i, len(df_id)-1):
                index = df_id.loc[j, "index"]
                if(df_id.loc[j + 1, "supplied_at"].month - df_id.loc[j, "supplied_at"].month < 3):
                    dataset_final.loc[index, "last_year_mean"] =  df_id.loc[i, "mean"]
                    dataset_final.loc[index, "last_year_sum"] =  df_id.loc[i, "sum"]

# drop data that doesn't contain last year data
for i in dataset_final.index:
    if not isinstance(dataset_final.loc[i, "last_year_mean"], float):
        dataset_final.drop(i, inplace=True)
        
dataset_final.reset_index(inplace=True, drop=True)

# %%
# add price data
dataset_final["price"] = ""

for i in dataset_final.index:
    for j in df_price.index:
        if (dataset_final.loc[i, "supplied_at"].year == df_price.loc[j, "date"].year and 
        dataset_final.loc[i, "supplied_at"].month == df_price.loc[j, "date"].month):
            dataset_final.loc[i, "price"] = df_price.loc[j, "price"]

# %%
dataset_final.tail()
# Out:
#       customer_id         supplied_at  volume  size     sum       mean  \
# 5250    8622750.0 2022-02-11 10:20:00   191.1   446  1249.0  10.495798
# 5251    8622750.0 2022-02-24 15:19:00   132.1   446  1249.0  10.495798
# 5252    8622770.0 2021-12-08 10:03:00    86.7   446   543.5   4.529167
# 5253    8622770.0 2022-01-08 17:01:00   159.8   446   543.5   4.529167
# 5254    8622770.0 2022-02-11 09:30:00   169.8   446   543.5   4.529167
#
#         matemp    mltemp    mhtemp     mwind    msnowacc     msnow      msun  \
# 5250  4.068750  7.531250  0.906250  2.587500   98.375000  6.500000  4.625000
# 5251  2.130769  5.100000 -0.946154  3.915385  102.384615  5.461538  3.838462
# 5252 -5.710000 -2.293333 -8.980000  3.543333    0.866667  0.600000  3.303333
# 5253  2.629032  5.838710 -0.506452  3.116129   31.451613  4.193548  3.287097
# 5254  2.900000  6.247059  0.038235  3.094118   85.441176  6.352941  3.611765
#
#         mhumidi  mean_consumption  interval     last_supply_time  \
# 5250  69.187500         11.943750      16.0  2022-01-26 13:14:00
# 5251  74.076923         10.161538      13.0  2022-02-11 10:20:00
# 5252  69.866667          2.890000      30.0  2021-11-08 14:37:00
# 5253  71.290323          5.154839      31.0  2021-12-08 10:03:00
# 5254  73.558824          4.994118      34.0  2022-01-08 17:01:00
#
#      last_year_mean last_year_sum price
# 5250       9.901754        1128.8   112
# 5251       9.901754        1128.8   112
# 5252        4.42303         729.8   112
# 5253        4.42303         729.8   107
# 5254        4.42303         729.8   112

# %%
len(dataset_final)
# Out:
# 5255

# %%
Traing_Test = dataset_final
Traing_Test.to_csv(PATH_SAVE, index=False)
